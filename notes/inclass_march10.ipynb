# %% [markdown]
# ## Pandas fundamentals

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
names = ['Mercury', 'Venus', 'Earth']
values = [0.3e24, 4.87e24, 5.97e24]

# %%
masses = pd.Series(values, index=names)
masses
# Out:
# Mercury    3.000000e+23
# Venus      4.870000e+24
# Earth      5.970000e+24
# dtype: float64

# %%
masses.shape
# Out:
# (3,)

# %%
masses.to_numpy()
# Out:
# array([3.00e+23, 4.87e+24, 5.97e+24])

# %%
masses.to_csv('mymassfile.csv')

# %%
masses2 = {'Mercury':3e23, 'Venus':4.87e24,'Earth':5.97e24}
masses2
# Out:
# {'Mercury': 3e+23, 'Venus': 4.87e+24, 'Earth': 5.97e+24}

# %%
myseries = pd.Series(masses2)
myseries
# Out:
# Mercury    3.000000e+23
# Venus      4.870000e+24
# Earth      5.970000e+24
# dtype: float64

# %%
masses.plot()
# Out:
# <Axes: >

# %%
masses.plot(kind='bar')
# Out:
# <Axes: >

# %%
masses.plot?

# %%
masses.plot(kind='pie')
# Out:
# <Axes: >

# %%
newseries = np.log(masses)/masses**2
newseries
# Out:
# Mercury    6.006452e-46
# Venus      2.396820e-48
# Earth      1.600655e-48
# dtype: float64

# %%
masses
# Out:
# Mercury    3.000000e+23
# Venus      4.870000e+24
# Earth      5.970000e+24
# dtype: float64

# %%
masses.values
# Out:
# array([3.00e+23, 4.87e+24, 5.97e+24])

# %%
masses.index
# Out:
# Index(['Mercury', 'Venus', 'Earth'], dtype='object')

# %%
masses['Venus']
# Out:
# 4.87e+24

# %%
masses.loc['Venus']
# Out:
# 4.87e+24

# %%
masses.iloc[1]
# Out:
# 4.87e+24

# %%
masses.loc['Mercury':'Venus']
# Out:
# Mercury    3.000000e+23
# Venus      4.870000e+24
# dtype: float64

# %%
masses.iloc[0:2]
# Out:
# Mercury    3.000000e+23
# Venus      4.870000e+24
# dtype: float64

# %%
masses.loc[masses>3e23]
# Out:
# Venus    4.870000e+24
# Earth    5.970000e+24
# dtype: float64

# %%
masses>3e23
# Out:
# Mercury    False
# Venus       True
# Earth       True
# dtype: bool

# %% [markdown]
# ### Dataframes

# %%
data = {'mass': [0.3e24,4.87e24,5.97e24],
        'diameter':[4879e3,12104e3,12756e3],
        'rotation_period':[1407.6, np.nan, 23.9]
       }

# %%
data
# Out:
# {'mass': [3e+23, 4.87e+24, 5.97e+24],
#  'diameter': [4879000.0, 12104000.0, 12756000.0],
#  'rotation_period': [1407.6, nan, 23.9]}

# %%
df = pd.DataFrame(data)
df
# Out:
#            mass    diameter  rotation_period
# 0  3.000000e+23   4879000.0           1407.6
# 1  4.870000e+24  12104000.0              NaN
# 2  5.970000e+24  12756000.0             23.9

# %%
df = pd.DataFrame(data,index=names)
df
# Out:
#                  mass    diameter  rotation_period
# Mercury  3.000000e+23   4879000.0           1407.6
# Venus    4.870000e+24  12104000.0              NaN
# Earth    5.970000e+24  12756000.0             23.9

# %%
df.head(1)
# Out:
#                  mass   diameter  rotation_period
# Mercury  3.000000e+23  4879000.0           1407.6

# %%
df.tail(1)
# Out:
#                mass    diameter  rotation_period
# Earth  5.970000e+24  12756000.0             23.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Mercury to Earth
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mass             3 non-null      float64
#  1   diameter         3 non-null      float64
#  2   rotation_period  2 non-null      float64
# dtypes: float64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#                mass      diameter  rotation_period
# count  3.000000e+00  3.000000e+00         2.000000
# mean   3.713333e+24  9.913000e+06       715.750000
# std    3.006765e+24  4.371744e+06       978.423653
# min    3.000000e+23  4.879000e+06        23.900000
# 25%    2.585000e+24  8.491500e+06       369.825000
# 50%    4.870000e+24  1.210400e+07       715.750000
# 75%    5.420000e+24  1.243000e+07      1061.675000
# max    5.970000e+24  1.275600e+07      1407.600000

# %%
df.describe?

# %%
describe = df.describe()
describe
# Out:
#                mass      diameter  rotation_period
# count  3.000000e+00  3.000000e+00         2.000000
# mean   3.713333e+24  9.913000e+06       715.750000
# std    3.006765e+24  4.371744e+06       978.423653
# min    3.000000e+23  4.879000e+06        23.900000
# 25%    2.585000e+24  8.491500e+06       369.825000
# 50%    4.870000e+24  1.210400e+07       715.750000
# 75%    5.420000e+24  1.243000e+07      1061.675000
# max    5.970000e+24  1.275600e+07      1407.600000

# %%
describe.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.mean()
# Out:
# mass               3.713333e+24
# diameter           9.913000e+06
# rotation_period    7.157500e+02
# dtype: float64

# %%
df['diameter']
# Out:
# Mercury     4879000.0
# Venus      12104000.0
# Earth      12756000.0
# Name: diameter, dtype: float64

# %%
df.diameter
# Out:
# Mercury     4879000.0
# Venus      12104000.0
# Earth      12756000.0
# Name: diameter, dtype: float64

# %%
df.diameter.mean()
# Out:
# 9913000.0

# %%
df.diameter.plot(kind='barh')
# Out:
# <Axes: >

# %%
df.loc['Mercury']
# Out:
# mass               3.000000e+23
# diameter           4.879000e+06
# rotation_period    1.407600e+03
# Name: Mercury, dtype: float64

# %%
df.iloc[0]
# Out:
# mass               3.000000e+23
# diameter           4.879000e+06
# rotation_period    1.407600e+03
# Name: Mercury, dtype: float64

# %%
df
# Out:
#                  mass    diameter  rotation_period
# Mercury  3.000000e+23   4879000.0           1407.6
# Venus    4.870000e+24  12104000.0              NaN
# Earth    5.970000e+24  12756000.0             23.9

# %%
df.loc['Earth','mass']
# Out:
# 5.97e+24

# %%
df.iloc[2,0]
# Out:
# 5.97e+24

# %%
volume = 4/3 * np.pi * (df.diameter / 2)**3
volume
# Out:
# Mercury    6.081225e+19
# Venus      9.285074e+20
# Earth      1.086781e+21
# Name: diameter, dtype: float64

# %%
df.mass/volume
# Out:
# Mercury    4933.216530
# Venus      5244.977070
# Earth      5493.285577
# dtype: float64

# %%
df
# Out:
#                  mass    diameter  rotation_period
# Mercury  3.000000e+23   4879000.0           1407.6
# Venus    4.870000e+24  12104000.0              NaN
# Earth    5.970000e+24  12756000.0             23.9

# %%
df.density = df.mass/volume
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577

# %% [markdown]
# ### merging data

# %%
temperature= pd.Series([167, 464, 15, -65], 
                       index=['Mercury','Venus','Earth','Mars'],
                       name='temperature')
temperature
# Out:
# Mercury    167
# Venus      464
# Earth       15
# Mars       -65
# Name: temperature, dtype: int64

# %%
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577

# %%
df.join(temperature)
# Out:
#                  mass    diameter  rotation_period      density  temperature
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530          167
# Venus    4.870000e+24  12104000.0              NaN  5244.977070          464
# Earth    5.970000e+24  12756000.0             23.9  5493.285577           15

# %%
df.join(temperature, how='right')
# Out:
#                  mass    diameter  rotation_period      density  temperature
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530          167
# Venus    4.870000e+24  12104000.0              NaN  5244.977070          464
# Earth    5.970000e+24  12756000.0             23.9  5493.285577           15
# Mars              NaN         NaN              NaN          NaN          -65

# %%
df.loc['Mars','mass'] = 6.39e23
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Mars     6.390000e+23         NaN              NaN          NaN

# %%
df.loc['Mars','diameter'] = 6.779e6
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Mars     6.390000e+23   6779000.0              NaN          NaN

# %%
df.loc['Mars','rotation_period'] = 24.5
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Mars     6.390000e+23   6779000.0             24.5          NaN

# %%
df.loc['Mars','density'] = 3933
df
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Mars     6.390000e+23   6779000.0             24.5  3933.000000

# %%
new_df = df.reindex(['Earth','Venus','Mars','Mercury'])
new_df
# Out:
#                  mass    diameter  rotation_period      density
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Mars     6.390000e+23   6779000.0             24.5  3933.000000
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530

# %%
another_df = df[['mass','density']]
another_df
# Out:
#                  mass      density
# Mercury  3.000000e+23  4933.216530
# Venus    4.870000e+24  5244.977070
# Earth    5.970000e+24  5493.285577
# Mars     6.390000e+23  3933.000000

# %%
df = df.join(temperature)

# %%
df
# Out:
#                  mass    diameter  rotation_period      density  temperature
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530          167
# Venus    4.870000e+24  12104000.0              NaN  5244.977070          464
# Earth    5.970000e+24  12756000.0             23.9  5493.285577           15
# Mars     6.390000e+23   6779000.0             24.5  3933.000000          -65

# %%
df.plot(kind='scatter',x='mass',y='diameter')
# Out:
# <Axes: xlabel='mass', ylabel='diameter'>

# %%
df.plot(kind='bar',y='mass')
# Out:
# <Axes: >

# %%
remove = df.drop(columns='temperature')
remove
# Out:
#                  mass    diameter  rotation_period      density
# Mercury  3.000000e+23   4879000.0           1407.6  4933.216530
# Venus    4.870000e+24  12104000.0              NaN  5244.977070
# Earth    5.970000e+24  12756000.0             23.9  5493.285577
# Mars     6.390000e+23   6779000.0             24.5  3933.000000

# %%
import pooch
POOCH = pooch.create(
    path=pooch.os_cache("noaa-data"),
    base_url="doi:10.5281/zenodo.5564850/",
    registry={
        "data.txt": "md5:5129dcfd19300eb8d4d8d1673fcfbcb4",
    },
)
datafile = POOCH.fetch("data.txt")
datafile
# Out:
# '/home/danielmw/.cache/noaa-data/data.txt'

# %%
df = pd.read_csv('/home/danielmw/.cache/noaa-data/data.txt',
                sep='\s+')
df
# Out:
#      WBANNO  LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0     64756  20170101   2.422     -73.74     41.79          6.6         -5.4
# 1     64756  20170102   2.422     -73.74     41.79          4.0         -6.8
# 2     64756  20170103   2.422     -73.74     41.79          4.9          0.7
# 3     64756  20170104   2.422     -73.74     41.79          8.7         -1.6
# 4     64756  20170105   2.422     -73.74     41.79         -0.5         -4.6
# ..      ...       ...     ...        ...       ...          ...          ...
# 360   64756  20171227   2.622     -73.74     41.79         -6.7        -19.3
# 361   64756  20171228   2.622     -73.74     41.79        -10.3        -21.5
# 362   64756  20171229   2.622     -73.74     41.79         -9.4        -19.0
# 363   64756  20171230   2.622     -73.74     41.79         -7.1        -18.9
# 364   64756  20171231   2.622     -73.74     41.79        -12.3        -21.8
#
# ...

# %%
df.describe()
# Out:
#         WBANNO      LST_DATE      CRX_VN     LONGITUDE      LATITUDE  \
# count    365.0  3.650000e+02  365.000000  3.650000e+02  3.650000e+02
# mean   64756.0  2.017067e+07    2.470767 -7.374000e+01  4.179000e+01
# std        0.0  3.454755e+02    0.085997  5.265234e-13  3.842198e-13
# min    64756.0  2.017010e+07    2.422000 -7.374000e+01  4.179000e+01
# 25%    64756.0  2.017040e+07    2.422000 -7.374000e+01  4.179000e+01
# 50%    64756.0  2.017070e+07    2.422000 -7.374000e+01  4.179000e+01
# 75%    64756.0  2.017100e+07    2.422000 -7.374000e+01  4.179000e+01
# max    64756.0  2.017123e+07    2.622000 -7.374000e+01  4.179000e+01
#
#        T_DAILY_MAX  T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_AVG  P_DAILY_CALC  ...  \
# count   365.000000   365.000000    365.000000   365.000000    365.000000  ...
# mean    -11.717534   -23.367671    -17.545205   -17.431781    -24.604384  ...
# std     524.299309   523.668165    523.978586   523.982545    523.567928  ...
# ...

# %%
df.T_DAILY_MIN.plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('/home/danielmw/.cache/noaa-data/data.txt',
                sep='\s+',na_values=[-9999, -99],
                parse_dates=[1])

# %%
df.T_DAILY_MEAN.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#      WBANNO   LST_DATE  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# 0     64756 2017-01-01   2.422     -73.74     41.79          6.6         -5.4
# 1     64756 2017-01-02   2.422     -73.74     41.79          4.0         -6.8
# 2     64756 2017-01-03   2.422     -73.74     41.79          4.9          0.7
# 3     64756 2017-01-04   2.422     -73.74     41.79          8.7         -1.6
# 4     64756 2017-01-05   2.422     -73.74     41.79         -0.5         -4.6
# ..      ...        ...     ...        ...       ...          ...          ...
# 360   64756 2017-12-27   2.622     -73.74     41.79         -6.7        -19.3
# 361   64756 2017-12-28   2.622     -73.74     41.79        -10.3        -21.5
# 362   64756 2017-12-29   2.622     -73.74     41.79         -9.4        -19.0
# 363   64756 2017-12-30   2.622     -73.74     41.79         -7.1        -18.9
# 364   64756 2017-12-31   2.622     -73.74     41.79        -12.3        -21.8
#
# ...

# %%
df = df.set_index('LST_DATE')
df
# Out:
#             WBANNO  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# LST_DATE
# 2017-01-01   64756   2.422     -73.74     41.79          6.6         -5.4
# 2017-01-02   64756   2.422     -73.74     41.79          4.0         -6.8
# 2017-01-03   64756   2.422     -73.74     41.79          4.9          0.7
# 2017-01-04   64756   2.422     -73.74     41.79          8.7         -1.6
# 2017-01-05   64756   2.422     -73.74     41.79         -0.5         -4.6
# ...            ...     ...        ...       ...          ...          ...
# 2017-12-27   64756   2.622     -73.74     41.79         -6.7        -19.3
# 2017-12-28   64756   2.622     -73.74     41.79        -10.3        -21.5
# 2017-12-29   64756   2.622     -73.74     41.79         -9.4        -19.0
# 2017-12-30   64756   2.622     -73.74     41.79         -7.1        -18.9
# 2017-12-31   64756   2.622     -73.74     41.79        -12.3        -21.8
#
# ...

# %%
df.loc['2017-07-01':'2017-07-31']
# Out:
#             WBANNO  CRX_VN  LONGITUDE  LATITUDE  T_DAILY_MAX  T_DAILY_MIN  \
# LST_DATE
# 2017-07-01   64756   2.422     -73.74     41.79         28.0         19.7
# 2017-07-02   64756   2.422     -73.74     41.79         29.8         18.4
# 2017-07-03   64756   2.422     -73.74     41.79         28.3         15.0
# 2017-07-04   64756   2.422     -73.74     41.79         26.8         12.6
# 2017-07-05   64756   2.422     -73.74     41.79         28.0         11.9
# 2017-07-06   64756   2.422     -73.74     41.79         25.7         14.3
# 2017-07-07   64756   2.422     -73.74     41.79         25.8         16.8
# 2017-07-08   64756   2.422     -73.74     41.79         29.0         15.3
# 2017-07-09   64756   2.422     -73.74     41.79         26.3         10.9
# 2017-07-10   64756   2.422     -73.74     41.79         27.6         11.8
# 2017-07-11   64756   2.422     -73.74     41.79         27.4         19.2
# ...

# %%
df.loc['2017-07-01':'2017-07-31'].mean(numeric_only=True)
# Out:
# WBANNO                     64756.000000
# CRX_VN                         2.422000
# LONGITUDE                    -73.740000
# LATITUDE                      41.790000
# T_DAILY_MAX                   26.912903
# T_DAILY_MIN                   15.183871
# T_DAILY_MEAN                  21.048387
# T_DAILY_AVG                   20.993548
# P_DAILY_CALC                   2.732258
# SOLARAD_DAILY                 20.566129
# SUR_TEMP_DAILY_MAX            37.409677
# SUR_TEMP_DAILY_MIN            14.754839
# SUR_TEMP_DAILY_AVG            23.854839
# RH_DAILY_MAX                  94.209677
# RH_DAILY_MIN                  52.183871
# RH_DAILY_AVG                  76.280645
# SOIL_MOISTURE_5_DAILY          0.131226
# SOIL_MOISTURE_10_DAILY         0.115774
# SOIL_MOISTURE_20_DAILY         0.116613
# SOIL_MOISTURE_50_DAILY         0.121032
# SOIL_MOISTURE_100_DAILY        0.156677
# SOIL_TEMP_5_DAILY             24.993548
# SOIL_TEMP_10_DAILY            24.980645
# ...

# %%
df[['T_DAILY_MIN','T_DAILY_MEAN','T_DAILY_MAX']].plot()
# Out:
# <Axes: xlabel='LST_DATE'>

# %%
dftemp = df[['T_DAILY_MIN','T_DAILY_MEAN','T_DAILY_MAX']]
dftemp
# Out:
#             T_DAILY_MIN  T_DAILY_MEAN  T_DAILY_MAX
# LST_DATE
# 2017-01-01         -5.4           0.6          6.6
# 2017-01-02         -6.8          -1.4          4.0
# 2017-01-03          0.7           2.8          4.9
# 2017-01-04         -1.6           3.6          8.7
# 2017-01-05         -4.6          -2.5         -0.5
# ...                 ...           ...          ...
# 2017-12-27        -19.3         -13.0         -6.7
# 2017-12-28        -21.5         -15.9        -10.3
# 2017-12-29        -19.0         -14.2         -9.4
# 2017-12-30        -18.9         -13.0         -7.1
# 2017-12-31        -21.8         -17.0        -12.3
#
# [365 rows x 3 columns]

# %%
dftemp.resample('MS').mean().plot()
# Out:
# <Axes: xlabel='LST_DATE'>

# %%
dftemp.resample('W').mean().plot()
# Out:
# <Axes: xlabel='LST_DATE'>
